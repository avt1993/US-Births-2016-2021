# %%
import pandas as pd
import plotly.express as px
import json
import plotly.graph_objects as go

# %%
df = pd.read_csv('StateGovernors.csv')
df
# Out:
#      StateFull StateAbbrev  GovernorNumber             GovernorName  \
# 0      Alabama          AL               1       William Wyatt Bibb
# 1      Alabama          AL               2              Thomas Bibb
# 2      Alabama          AL               3           Israel Pickens
# 3      Alabama          AL               4              John Murphy
# 4      Alabama          AL               5            Gabriel Moore
# ...        ...         ...             ...                      ...
# 2582   Wyoming          WY              29    Michael John Sullivan
# 2583   Wyoming          WY              30    James Edward Geringer
# 2584   Wyoming          WY              31  David Duane Freudenthal
# 2585   Wyoming          WY              32      Matthew Hansen Mead
# 2586   Wyoming          WY              33              Mark Gordon
#
#              TookOffice         LeftOffice       PartyAffiliation PartyAbbrev
# ...

# %%
df_filtered = df[(df['TookOffice'].str.contains(r'\b(2011|2012|2013|2014|2015|2016|2017|2018|2019|2020|2021)\b', regex=True)) | (df['LeftOffice'].str.contains(r'\b(2016|2017|2018|2019|2020|2021)\b', regex=True))].reset_index()
# Out:
# /var/folders/0p/ymgcc2_s2fz5y2m7s2hb1dzw0000gn/T/ipykernel_4376/1030464046.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_filtered = df[(df['TookOffice'].str.contains(r'\b(2011|2012|2013|2014|2015|2016|2017|2018|2019|2020|2021)\b', regex=True)) | (df['LeftOffice'].str.contains(r'\b(2016|2017|2018|2019|2020|2021)\b', regex=True))].reset_index()
#     index      StateFull StateAbbrev  GovernorNumber  \
# 0      32        Alabama          AL              33
# 1      59        Alabama          AL              60
# 2      60        Alabama          AL              61
# 3      73         Alaska          AK              13
# 4      74         Alaska          AK              14
# 5     101        Arizona          AZ              27
# 6     158       Arkansas          AR              57
# 7     197     California          CA              39
# 8     198     California          CA              40
# ...

# %%
df_filtered.to_csv('StateGovernors_filtered.csv', index = False)

# %%
df = pd.read_csv('state_df.csv')
df_sorted = df.sort_values('State', ascending=True)
df_sorted
df_sorted.to_csv('state_df.csv', index = False)
